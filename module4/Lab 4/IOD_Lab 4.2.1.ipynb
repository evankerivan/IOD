# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.1: Feature Selection

# %% [markdown]
# In this lab, we delve into the fundamental concept of feature selection. We start by conducting correlation analysis to identify relevant features for our regression model. By examining the relationship between each feature and the target variable, we aim to pick the most influential features. Additionally, we explore the significance of cross validation in model evaluation and how it relates to feature selection. Through cross validation, we ensure that our model generalises well to unseen data by assessing its performance across multiple validation sets.

# %% [markdown]
# ### 1. Load & Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### 1.1 Load Data

# %%
# Read CSV
wine_csv = pd.read_csv('winequality_merged.csv')
df= wine_csv

# %% [markdown]
# #### 1.2 Explore Data (Exploratory Data Analysis)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# 1      9.8        5         1
# 2      9.8        5         1
# 3      9.8        6         1
# 4      9.4        5         1

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality     red_wine
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378     0.246114
# std       0.160787     0.148806     1.192712     0.873255     0.430779
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     0.000000
# 50%       3.210000     0.510000    10.300000     6.000000     0.000000
# 75%       3.320000     0.600000    11.300000     6.000000     0.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  red_wine              6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
# red_wine                   -0.348821   0.512678            -0.471644
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
# red_wine                         -0.700357  0.390645  0.329129   0.487218
#
#                        alcohol   quality  red_wine
# fixed acidity        -0.095452 -0.076743  0.486740
# volatile acidity     -0.037640 -0.265699  0.653036
# citric acid          -0.010493  0.085532 -0.187397
# residual sugar       -0.359415 -0.036980 -0.348821
# chlorides            -0.256916 -0.200666  0.512678
# free sulfur dioxide  -0.179838  0.055463 -0.471644
# total sulfur dioxide -0.265740 -0.041385 -0.700357
# density              -0.686745 -0.305858  0.390645
# pH                    0.121248  0.019506  0.329129
# sulphates            -0.003029  0.038485  0.487218
# alcohol               1.000000  0.444319 -0.032970
# quality               0.444319  1.000000 -0.119323
# red_wine             -0.032970 -0.119323  1.000000

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_58e58_row0_col0, #T_58e58_row1_col1, #T_58e58_row2_col2, #T_58e58_row3_col3, #T_58e58_row4_col4, #T_58e58_row5_col5, #T_58e58_row6_col6, #T_58e58_row7_col7, #T_58e58_row8_col8, #T_58e58_row9_col9, #T_58e58_row10_col10, #T_58e58_row11_col11, #T_58e58_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_58e58_row0_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_58e58_row0_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_58e58_row0_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_58e58_row0_col4, #T_58e58_row0_col9, #T_58e58_row9_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_58e58_row0_col5, #T_58e58_row9_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_58e58_row0_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_58e58_row0_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_58e58_row0_col8, #T_58e58_row8_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_58e58_row0_col10 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_58e58_row0_col11, #T_58e58_row10_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_58e58_row0_col12, #T_58e58_row9_col12 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_58e58_row1_col0, #T_58e58_row2_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_58e58_row1_col2, #T_58e58_row2_col8, #T_58e58_row6_col0, #T_58e58_row6_col1, #T_58e58_row6_col4, #T_58e58_row6_col9, #T_58e58_row6_col12, #T_58e58_row7_col10, #T_58e58_row7_col11, #T_58e58_row10_col3, #T_58e58_row10_col7, #T_58e58_row12_col5, #T_58e58_row12_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_58e58_row1_col3, #T_58e58_row3_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_58e58_row1_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_58e58_row1_col5, #T_58e58_row4_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_58e58_row1_col6, #T_58e58_row4_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_58e58_row1_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_58e58_row1_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_58e58_row1_col9, #T_58e58_row9_col8, #T_58e58_row10_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_58e58_row1_col10 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_58e58_row1_col11 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_58e58_row1_col12 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_58e58_row2_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_58e58_row2_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_58e58_row2_col3, #T_58e58_row5_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_58e58_row2_col4, #T_58e58_row4_col6, #T_58e58_row6_col10, #T_58e58_row8_col11, #T_58e58_row9_col6, #T_58e58_row11_col9 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_58e58_row2_col6, #T_58e58_row4_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_58e58_row2_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_58e58_row2_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_58e58_row2_col10 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_58e58_row2_col11, #T_58e58_row5_col10 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_58e58_row2_col12, #T_58e58_row4_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_58e58_row3_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_58e58_row3_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_58e58_row3_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_58e58_row3_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_58e58_row3_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_58e58_row3_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_58e58_row3_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_58e58_row3_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_58e58_row3_col10, #T_58e58_row9_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_58e58_row3_col11, #T_58e58_row3_col12 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_58e58_row4_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_58e58_row4_col1, #T_58e58_row5_col3, #T_58e58_row9_col7 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_58e58_row4_col5, #T_58e58_row11_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_58e58_row4_col7 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_58e58_row4_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_58e58_row4_col10, #T_58e58_row7_col8, #T_58e58_row10_col6 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_58e58_row4_col12 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_58e58_row5_col0, #T_58e58_row8_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_58e58_row5_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_58e58_row5_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_58e58_row5_col6 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_58e58_row5_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_58e58_row5_col8, #T_58e58_row12_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_58e58_row5_col9, #T_58e58_row6_col8, #T_58e58_row8_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_58e58_row5_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_58e58_row5_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_58e58_row6_col2, #T_58e58_row8_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_58e58_row6_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_58e58_row6_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_58e58_row6_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_58e58_row6_col11 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_58e58_row7_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_58e58_row7_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_58e58_row7_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_58e58_row7_col3, #T_58e58_row11_col10 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_58e58_row7_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_58e58_row7_col5, #T_58e58_row10_col8, #T_58e58_row11_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_58e58_row7_col6 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_58e58_row7_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_58e58_row7_col12 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_58e58_row8_col1, #T_58e58_row8_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_58e58_row8_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_58e58_row8_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_58e58_row8_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_58e58_row8_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_58e58_row8_col12 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_58e58_row9_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_58e58_row9_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_58e58_row9_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_58e58_row9_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_58e58_row9_col11, #T_58e58_row11_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_58e58_row10_col1, #T_58e58_row10_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_58e58_row10_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_58e58_row10_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_58e58_row10_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_58e58_row10_col11 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_58e58_row11_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_58e58_row11_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_58e58_row11_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_58e58_row11_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_58e58_row11_col6, #T_58e58_row12_col10 {
#   background-color: #bcd2f7;

# %%
Q1 = df["red_wine"].quantile(0.25)
Q3 = df["red_wine"].quantile(0.75)
IQR=Q3-Q1
condition1 = df["red_wine"]< Q1 -1.5 *IQR
condition2 = df["red_wine"] >Q3 +1.5 *IQR
outlier = df[(condition1) | (condition2)]
print(outlier)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  red_wine
# 0         9.4        5         1
# 1         9.8        5         1
# 2         9.8        5         1
# 3         9.8        6         1
# 4         9.4        5         1
# ...       ...      ...       ...
# 1594     10.5        5         1
# 1595     11.2        6         1
# 1596     11.0        6         1
# 1597     10.2        5         1
# 1598     11.0        6         1
#
# [1599 rows x 13 columns]

# %%
df["quality"].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
plt.hist(df["quality"])
# Out:
# (array([  30.,  216.,    0., 2138.,    0., 2836., 1079.,    0.,  193.,
#            5.]),
#  array([3. , 3.6, 4.2, 4.8, 5.4, 6. , 6.6, 7.2, 7.8, 8.4, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize = 8,20)
df.plot(kind="box")
# Out:
#   Cell In[11], line 1
#     plt.figure(figsize = 8,20)
#                              ^
# SyntaxError: positional argument follows keyword argument

# %%
df.boxplot(column=['total sulfur dioxide'])

# %%
features = ['alcohol',"citric acid","free sulfur dioxide", "sulphates"]
# Calculate Q1, Q3, and IQR for each feature
Q1 = df[features].quantile(0.25)
Q3 = df[features].quantile(0.75)
IQR = Q3 - Q1
for feature in features: 
    Q1_feature = Q1[feature] 
    Q3_feature = Q3[feature]
# Identify outliers for each feature
    outlier_condition = ((df[features] < (Q1 - 1.5 * IQR)) | 
                     (df[features] > (Q3 + 1.5 * IQR))).any(axis=1)
# Exclude outliers
data_no_outliers = df[~outlier_condition]

# %%
data_no_outliers.head()

# %% [markdown]
# ### 2. Set Target Variable

# %% [markdown]
# Create a target variable for wine quality.

# %%
y= df['quality']
y_no_outliers= data_no_outliers["quality"]

# %% [markdown]
# ### 3. Set Predictor Variables

# %% [markdown]
# Create a predictor matrix with variables of your choice. State your reasoning for the choices you make.

# %%
X = df[features].values
X.shape

# %%
X_1=data_no_outliers

# %% [markdown]
# ### 4. Using Linear Regression Create a Model and Test Score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_1_train, X_1_test, y_no_outliers_train, y_no_outliers_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Create a model for Linear Regression
model= LinearRegression()
model1 =LinearRegression()

# Fit the model with the Training data
model.fit(X_train,y_train)
model1.fit(X_1_train,y_no_outliers_train)

# Calculate the score (R^2 for Regression) for Training Data
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Calculate the score (R^2 for Regression) for Testing Data

# %%
model= LinearRegression()
model1 =LinearRegression()

# Fit the model with the Training data
model.fit(X_train,y_train)
model1.fit(X_1_train,y_no_outliers_train)

# Calculate the score (R^2 for Regression) for Training Data
print(model1.score(X_train,y_train))
print(model1.score(X_1_test,y_no_outliers_test))
# Calculate the score (R^2 for Regression) for Testing Data

# %% [markdown]
# ## BONUS: Cross validation

# %%
# Cross validation
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

# %%
# Set up 5-fold cross validation
k_fold = KFold(5, shuffle=True)
train_scores = []
train_rmse = []
test_scores = []
test_rmse = []

for k, (train, test) in enumerate(k_fold.split(X)):

    # Get training and test sets for X and y

    # Fit model with training set

    # Make predictions with training and test set

    # Score R2 and RMSE on training and test sets and store in list

# Create a metrics_df dataframe to display r2 and rmse scores

# %%
# Describe the metrics

# %% [markdown]
# ### 5. Feature Selection
#
# What's your score (R^2 for Regression) for Testing Data?
#
# How many feature have you selected? Can you improve your score by selecting different features?

# %% [markdown]
# **Please continue with Lab 4.2.2 with the same dataset.**

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
