# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('All-TabulatedReport__May120241200AM-Jun152024117PM.csv')
# Out:
# /var/folders/br/kn0p5yrn6d771z_m2v7qll780000gp/T/ipykernel_90665/2090118780.py:1: DtypeWarning: Columns (15,16,22,23,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('All-TabulatedReport__May120241200AM-Jun152024117PM.csv')

# %%
df.tail()
# Out:
#                       Time  BAM Monitor - AP (mb)  BAM Monitor - Flow (L/min)  \
# 63868  2024-06-15 13:07:00                    NaN                         NaN
# 63869  2024-06-15 13:08:00                    NaN                         NaN
# 63870  2024-06-15 13:10:00                    NaN                         NaN
# 63871  2024-06-15 13:12:00                    NaN                         NaN
# 63872  2024-06-15 13:16:00                    NaN                         NaN
#
#        BAM Monitor - LC  BAM Monitor - Memory (%)  \
# 63868               NaN                       NaN
# 63869               NaN                       NaN
# 63870               NaN                       NaN
# 63871               NaN                       NaN
# 63872               NaN                       NaN
#
#        BAM Monitor - PM10 - 0.5Hr (µg/m³)  BAM Monitor - PM10 - 1Hr (µg/m³)  \
# 63868                                 NaN                               NaN
# ...

# %%
df.describe()
# Out:
#        BAM Monitor - AP (mb)  BAM Monitor - Flow (L/min)  BAM Monitor - LC  \
# count                    0.0                         0.0               0.0
# mean                     NaN                         NaN               NaN
# std                      NaN                         NaN               NaN
# min                      NaN                         NaN               NaN
# 25%                      NaN                         NaN               NaN
# 50%                      NaN                         NaN               NaN
# 75%                      NaN                         NaN               NaN
# max                      NaN                         NaN               NaN
#
#        BAM Monitor - Memory (%)  BAM Monitor - PM10 - 0.5Hr (µg/m³)  \
# count                       0.0                        13117.000000
# mean                        NaN                           12.267058
# std                         NaN                           88.545493
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63873 entries, 0 to 63872
# Data columns (total 32 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Time                                       63873 non-null  object
#  1   BAM Monitor - AP (mb)                      0 non-null      float64
#  2   BAM Monitor - Flow (L/min)                 0 non-null      float64
#  3   BAM Monitor - LC                           0 non-null      float64
#  4   BAM Monitor - Memory (%)                   0 non-null      float64
#  5   BAM Monitor - PM10 - 0.5Hr (µg/m³)         13117 non-null  float64
#  6   BAM Monitor - PM10 - 1Hr (µg/m³)           13117 non-null  float64
#  7   BAM Monitor - PM10 - 24Hr (µg/m³)          13117 non-null  float64
#  8   BAM Monitor - PM10 - 3Hr (µg/m³)           13117 non-null  float64
#  9   BAM Monitor - PM10 (Hourly) (µg/m³)        1093 non-null   float64
# ...
