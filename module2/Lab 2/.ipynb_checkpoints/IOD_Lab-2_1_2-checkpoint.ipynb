# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.1.2
# # *Exploring Data*

# %% [markdown]
# ## Part 1: Continuous and Categorical Data

# %% [markdown]
# When we explore a dataset we usually produce textual and graphical output together, starting with a high-level overview of the data and gradually drilling down into the individual features and relationships between them.

# %% [markdown]
# Our most important libraries for this task are:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cause plots to be displayed in the notebook:
# %matplotlib inline

# %%
# Set the default figure size
plt.rcParams['figure.figsize'] = (10, 6)
sns.set(color_codes = True)

# %% [markdown]
# ## Data Profiling
#
# We actually start profiling the data when we first load it and check for input errors, as in the last lab. Once we have a DataFrame we can work with, however, things start getting more interesting.

# %% [markdown]
# **Load the file "bikeshare.csv" into a DataFrame named `bikes`, and check that it was loaded properly:**

# %%
bikes = pd.read_csv("bikeshare.csv")
bikes.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
def read_file(file_path):
        try:
            df = pd.read_csv(file_path)
        except e:
            print("Error loading file", file_path)
            return None
        return df
file_path = "bikeshare.csv"
df = read_file(file_path)
if df is not None:
    print(df.head())
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# We may want our program to capture particular features of the dataset into variables, but if we just want to get a feel for the data it is easier to use a higher-level Pandas method like `describe()`:
#
# **Use `describe` to get the description of datasets.**

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
bikes.describe().T
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# windspeed   17379.0     0.190098     0.122340  0.00     0.1045     0.1940
# casual      17379.0    35.676218    49.305030  0.00     4.0000    17.0000
# registered  17379.0   153.786869   151.357286  0.00    34.0000   115.0000
# cnt         17379.0   189.463088   181.387599  1.00    40.0000   142.0000
#
#                    75%         max
# instant     13034.5000  17379.0000
# season          3.0000      4.0000
# yr              1.0000      1.0000
# mnth           10.0000     12.0000
# hr             18.0000     23.0000
# holiday         0.0000      1.0000
# weekday         5.0000      6.0000
# workingday      1.0000      1.0000
# weathersit      2.0000      4.0000
# temp            0.6600      1.0000
# atemp           0.6212      1.0000
# hum             0.7800      1.0000
# windspeed       0.2537      0.8507
# casual         48.0000    367.0000
# registered    220.0000    886.0000
# cnt           281.0000    977.0000

# %% [markdown]
# ### Continuous Data

# %% [markdown]
# We may have to do a lot of work before we can produce presentable graphics, but we can start creating simple visualisations as soon as we have a DataFrame.
#
# We usually start charting variables one-by-one (although when several have the same range it may be preferable to overlay them, using a different colour or symbol for each).

# %% [markdown]
# **Use the `scatter` method of Pandas to create a scatter plot of `windspeed`, `temp`:**

# %%
df.plot.scatter("temp","windspeed")
# Out:
# <Axes: xlabel='temp', ylabel='windspeed'>

# %% [markdown]
# **The `scatter` method has various parameters for controlling the appearance of the chart. Experiment with `s` , `linewidths`, and `alpha` below:**

# %%
df.plot.scatter('temp','windspeed',s=3,linewidths=1, alpha=0.01)
# Out:
# <Axes: xlabel='temp', ylabel='windspeed'>

# %% [markdown]
# The scatterplot shows us the raw data. Our next step is usually to see how it is distributed, which is what the histogram is for:
#
# > A histogram is used for continuous data, where the bins represent ranges of data, while a bar chart is a plot of categorical variables. <sup>[1](#histfootnote)</sup>
#
# - **Identify continuous variables**
# - **Create histogram for those variables**

# %%
df['temp'].hist(figsize=(5,5),bins=50)
# Out:
# <Axes: >

# %% [markdown]
# What do the horizontal and vertical axes represent?

# %% [markdown]
# ANSWER:

# %% [markdown]
# *NOTE: Samples in a given bin are greater than the axis value of its left side and less than or equal to the axis value of its right side. (The left-most bin is an exception: it represents greater than or equal to.)*

# %% [markdown]
# The box-and-whisker plot provides a compact view of the major percentiles of the distribution:
#
# **Make a box and whisker plot for the column ``atemp``.**
#
# > The box extends from the lower to
# upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data.  Flier points are those past the end of the whiskers.

# %%
df.boxplot(['atemp'])
# Out:
# <Axes: >

# %% [markdown]
# This kind of plot really shines when we want to show several distributions at once (as long as they have compatible ranges).
#
# **Plot `atemp` and `windspeed` together. Change labels accordingly.**

# %%
month_1_bikes_shares = df[df['mnth']==1]
print(month_1_bikes_shares['mnth'].min(),month_1_bikes_shares['mnth'].max())
# Out:
# 1 1

# %%
plt.boxplot(month_1_bikes_shares['atemp'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e098490>,
#   <matplotlib.lines.Line2D at 0x13e0990d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x13e099b90>,
#   <matplotlib.lines.Line2D at 0x13e09a690>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13e0b3950>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e09b1d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e0996d0>],
#  'means': []}

# %%
plt.boxplot((df["atemp"],df['windspeed']),labels=('temp',"windspeed"))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e1374d0>,
#   <matplotlib.lines.Line2D at 0x13e144090>,
#   <matplotlib.lines.Line2D at 0x13e147ed0>,
#   <matplotlib.lines.Line2D at 0x13e080a50>],
#  'caps': [<matplotlib.lines.Line2D at 0x13e144bd0>,
#   <matplotlib.lines.Line2D at 0x13e1455d0>,
#   <matplotlib.lines.Line2D at 0x13e151490>,
#   <matplotlib.lines.Line2D at 0x13e151f90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13e136990>,
#   <matplotlib.lines.Line2D at 0x13e147550>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e1461d0>,
#   <matplotlib.lines.Line2D at 0x13e1529d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e137f10>,
#   <matplotlib.lines.Line2D at 0x13e0d6910>],
#  'means': []}

# %% [markdown]
# ### Classified Data
#
# Samples may represent different classes according to one or more categorical variables. Sometimes our goal is to discover these classes, or to train a classification model from samples that have been manually classified.

# %% [markdown]
# Here, the famous "Iris" dataset gets loaded from the UCI repository:

# %%
import urllib

# get Iris dataset from UCI Machine Learning Repository:
url = "http://goo.gl/HppjFh"
raw_data = urllib.request.urlopen(url)

# load the CSV file:
iris_data = pd.read_csv(raw_data, delimiter = ",",
                        names = ('sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'))

# %% [markdown]
# Note that the column names were overridden by the `names` argument of the Pandas `read.csv` method. This requires prior knowledge of the dataset, which we would normally get from a data dictionary (although sometimes we just have to figure it out for ourselves).

# %% [markdown]
# **Print the first few rows of this DataFrame:**

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# In this dataset, `species` has several possible values (representing the classes of the samples).
#
# **Find out distinct number of `species` and number of sample for each `species` in this dataset.**

# %%
print(iris_data['species'].value_counts())
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# We often need to calculate aggregate values within subgroups of the dataset. The Pandas DataFrame method for this is `groupby`.
#
# **Apply the `groupby` method to create a dataframe showing the `mean` of `sepal_length` and `sepal_width` by species for the above dataset.**

# %%
iris_data.groupby(by=['species']).mean()
iris_data_mean = iris_data.groupby('species').agg({'sepal_length': 'mean',"sepal_width":"mean"})
print(iris_data_mean)
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa             5.006        3.418
# Iris-versicolor         5.936        2.770
# Iris-virginica          6.588        2.974

# %% [markdown]
# **Using the dataframe generated by the previous `groupby` method, draw a barplot showing sepal width and length for each species using the Pandas plot method.**

# %%
iris_data_mean.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Draw a Scatterplot showing sepal width and length using the Pandas plot method.
#
# **[BONUS] Set `title`, `xlabel`, `ylabel` to the plot**

# %%
iris_data.plot(kind='scatter', x= 'sepal_length', y='sepal_width',title="Iris Sepal Length vs Width")
# Out:
# <Axes: title={'center': 'Iris Sepal Length vs Width'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# In this case, we already have different species, so we can colour the points accordingly. This is easy to do using the Seaborn library. Try using `lmplot` of seaborn library and use the parameter `hue` and `fit_reg = False`.
#
# **Draw a Scatterplot showing sepal width and length.**

# %%
# ANSWER
sns.lmplot(x ='sepal_length', y ='sepal_width', data = iris_data, fit_reg = False, hue= "sepal_length")

# Draw a Scatterplot showing sepal width and length:

# %% [markdown]
# **[BONUS] Draw a Scatterplot showing sepal width and length. Without using seaborn.**

# %%
iris_data.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# To find out why this function is called `lmplot`, try it again with `fit_reg` = True:
#
# **Draw a Scatterplot showing sepal width and length:**

# %%
sns.lmplot(x ='sepal_length', y ='sepal_width', data = iris_data, fit_reg = True, hue= "sepal_length")
# Draw a Scatterplot showing sepal width and length:

# %% [markdown]
# The Seaborn `jointplot` function charts a correlation along with both distributions:
#
# **Draw a jointplot showing sepal width and length:**

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris_data)

# %% [markdown]
# When we want to see all the correlations at once, we can use `pairplot`:
#
# **Draw a `pairplot` of the dataset:**

# %%
sns.pairplot(iris_data)

# %% [markdown]
# And, if the classes are known, we can apply colour using the `hue` parameter. Try this below:

# %%
sns.pairplot(iris_data, hue= "sepal_length")

# %% [markdown]
# Note that this gave us class-based distributions instead of an overall histogram, as well.

# %% [markdown]
# When we want to see numerical values of the correlations, the Pandas `corr` method provides a table of pair-wise correlations between the features in the DataFrame:

# %%
numeric_cols= iris_data.select_dtypes(float)
numeric_cols.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### High-Level Data Profiling Libraries

# %% [markdown]
# We need to master the basic data profiling functions because we will by using them frequently, for exploring data and answering ad hoc questions. In a production solution, we may need to incorporate specific data profiling code into our script so that we can automate data cleaning. However, when we just want to examine the data interactively before we start modelling, it is easier to use a high-level library like the following:
#
# > pip install sweetviz

# %%
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in /Applications/anaconda3/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (2.1.0)
# Requirement already satisfied: numpy>=1.16.0 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.3 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (3.7.1)
# Requirement already satisfied: tqdm>=4.43.0 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: scipy>=1.3.2 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (1.10.1)
# Requirement already satisfied: jinja2>=2.11.1 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: importlib-resources>=1.2.0 in /Applications/anaconda3/lib/python3.11/site-packages (from sweetviz) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Applications/anaconda3/lib/python3.11/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Applications/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Applications/anaconda3/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1
# [notice] To update, run: pip install --upgrade pip

# %%
# ANSWER
import pandas as pd
import sweetviz as sv
df = pd.read_csv("Meteorite_Landings.csv", parse_dates = ['year'], encoding = 'UTF-8')
df.head(10)
# Out:
# /var/folders/br/kn0p5yrn6d771z_m2v7qll780000gp/T/ipykernel_69363/3627910193.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("Meteorite_Landings.csv", parse_dates = ['year'], encoding = 'UTF-8')
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong               GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775000, 6.083330)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333    (56.183330, 10.233330)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000  (54.216670, -113.000000)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000   (16.883330, -99.900000)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000  (-33.166670, -64.950000)
# 5  01/01/1919 12:00:00 AM  32.10000   71.80000    (32.100000, 71.800000)
# 6  01/01/1949 12:00:00 AM  44.83333   95.16667    (44.833330, 95.166670)
# 7  01/01/1814 12:00:00 AM  44.21667    0.61667     (44.216670, 0.616670)
# 8  01/01/1930 12:00:00 AM -31.60000  -65.23333  (-31.600000, -65.233330)
# 9  01/01/1920 12:00:00 AM -30.86667  -64.55000  (-30.866670, -64.550000)

# %% [markdown]
# Use `analyze` and `show_html` of `sweetviz` to get an overview of the dataset.

# %%
# ANSWER
report= sv.analyze(df)
report.show_html('Report.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Part 2: Time Series and Geospatial Data

# %% [markdown]
# ### Time Series
#
# A time series is basically a series or a data frame with a time-based index column. Working with time series introduces a lot of challenges and possibilities, but most tasks are catered for by the standard libraries in Python.

# %% [markdown]
# Here is a history of air passenger counts by month, loaded into an ordinary DataFrame:

# %%
airpass = pd.read_csv('AirPassengers.csv')
airpass.head()
# Out:
#   TravelDate  Passengers
# 0   1/1/1949         112
# 1   2/1/1949         118
# 2   3/1/1949         132
# 3   4/1/1949         129
# 4   5/1/1949         121

# %%
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# Before going any further, the `TravelDate` column needs to be converted to the `datetime` type.

# %%
# ANSWER
airpass['TravelDate']= pd.to_datetime(airpass['TravelDate'])
airpass.head()
# Out:
#   TravelDate  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %% [markdown]
# Set `TravelDate` as index

# %%
# ANSWER
airpass = airpass.set_index('TravelDate')

# %% [markdown]
# Now, Pandas knows that the first column of this DataFrame is a datetime index, so it only shows one column of data:
#
# Use `head` to check.

# %%
airpass.head()
# Out:
#             Passengers
# TravelDate
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# Here's how to see the values of the index:

# %%
airpass.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='TravelDate', length=144, freq=None)

# %% [markdown]
# If we had multiple data columns but we only wanted to work with a time series of one of them, we could pull that column into a 1D time series:

# %%
ts = airpass['Passengers']

# %% [markdown]
# We use the datetime index exactly like a row number index:

# %%
print(ts['1949-01-01'])
# Out:
# 112

# %% [markdown]
# Or, we can refer to the row by its datetime equivalent:

# %%
from datetime import datetime
print(ts[datetime(1949,1,1)])
# Out:
# 112

# %% [markdown]
# Happily, Pandas makes it easy to slice data at a courser grain. We can refer to a whole year of data by omitting the month and day form the index:

# %%
print(ts['1949'])
# Out:
# TravelDate
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# Name: Passengers, dtype: int64

# %% [markdown]
# The most basic way to plot a time series is to let Pandas apply the default:

# %%
ts.plot();

# %% [markdown]
# ### Geospatial Data
#
# Geospatial data is map-based (although what constitutes a "map" can go beyond the familiar). Ultimately, geographic data  occurs either in bitmap (raster) form or vector (resizeable polygons). It is not unusual for the two kinds of data to be used together.
#
# Because borders are often complex, following river courses, mountain ranges, and so on, the files that describe their geometries can be large. To reduce file sizes and image rendering times, we prefer to work with polygons that are no more detailed than the maximum resolution we need for our task. For this reason, geospatial files are often available at several different resolutions.

# %% [markdown]
# There are several popular options for working with maps in Python. We will use folium for its breadth and its use of open-source data.

# %%
import folium

# %%
# Read SF Incidents data
crime_csv = pd.read_csv('SFPD_Incidents-Current_Year_2015.csv')
crime_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112331 entries, 0 to 112330
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IncidntNum  112331 non-null  int64
#  1   Category    112331 non-null  object
#  2   Descript    112331 non-null  object
#  3   DayOfWeek   112331 non-null  object
#  4   Date        112331 non-null  object
#  5   Time        112331 non-null  object
#  6   PdDistrict  112331 non-null  object
#  7   Resolution  112331 non-null  object
#  8   Address     112331 non-null  object
#  9   X           112331 non-null  float64
#  10  Y           112331 non-null  float64
#  11  Location    112331 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 10.3+ MB

# %% [markdown]
# Convert `Date` Column to DateTime and set as index

# %%
crime_csv.set_index('Date', inplace = True)

# %% [markdown]
# Draw a timeseries plot to visualise number of crimes for each day.

# %%
crime_csv.head()
# Out:
#             IncidntNum      Category                         Descript  \
# Date
# 09/20/2015   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED
# 09/20/2015   150827213       ASSAULT      INFLICT INJURY ON COHABITEE
# 09/20/2015   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE
# 09/20/2015   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)
# 09/20/2015   150827213       ASSAULT              MAYHEM WITH A KNIFE
#
#            DayOfWeek   Time PdDistrict      Resolution  \
# Date
# 09/20/2015    Sunday  23:54   RICHMOND       UNFOUNDED
# 09/20/2015    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 09/20/2015    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 09/20/2015    Sunday  23:45  INGLESIDE  ARREST, BOOKED
# 09/20/2015    Sunday  23:45  INGLESIDE  ARREST, BOOKED
#
#                              Address           X          Y  \
# Date
# 09/20/2015  3000 Block of CLEMENT ST -122.491851  37.781756
# 09/20/2015     100 Block of LOEHR ST -122.413676  37.712617
# 09/20/2015     100 Block of LOEHR ST -122.413676  37.712617
# 09/20/2015     100 Block of LOEHR ST -122.413676  37.712617
# 09/20/2015     100 Block of LOEHR ST -122.413676  37.712617
#
#                                          Location
# Date
# 09/20/2015  (37.7817557255921, -122.491851328976)
# 09/20/2015  (37.7126165766239, -122.413676487435)
# 09/20/2015  (37.7126165766239, -122.413676487435)
# 09/20/2015  (37.7126165766239, -122.413676487435)
# 09/20/2015  (37.7126165766239, -122.413676487435)

# %%
group_day=crime_csv.groupby(crime_csv.index)
group_day.size().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Using folium we can easily create a map. As it's SF data, by default we are using SF location.

# %%
def generateBaseMap(default_location=[37.76, -122.45], default_zoom_start=12):
    '''
    Create a base map
    '''
    base_map = folium.Map(
        location = default_location
        , control_scale = True
        , zoom_start = default_zoom_start
    )

    return base_map

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4f2024acb55de24c852f058e176e306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4f2024acb55de24c852f058e176e306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4f2024acb55de24c852f058e176e306 = L.map(
#                 &quot;map_b4f2024acb55de24c852f058e176e306&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#
#
#
#             var tile_layer_9cfc6c90b60ab1386086c845225d1d45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9cfc6c90b60ab1386086c845225d1d45.addTo(map_b4f2024acb55de24c852f058e176e306);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a marker in the map using `Folium.Marker` for first 100 rows of the dataset.

# %%
for index, row in crime_csv.head(100).iterrows():
    folium.Marker(
        location=[row['Y'], row['X']],
        popup=f"Date: {index}").add_to(base_map)
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4f2024acb55de24c852f058e176e306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4f2024acb55de24c852f058e176e306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4f2024acb55de24c852f058e176e306 = L.map(
#                 &quot;map_b4f2024acb55de24c852f058e176e306&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#
#
#
#             var tile_layer_9cfc6c90b60ab1386086c845225d1d45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9cfc6c90b60ab1386086c845225d1d45.addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#             tile_layer_9cfc6c90b60ab1386086c845225d1d45.addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#             var marker_693e6deb8601b5b691efadbd746893ae = L.marker(
#                 [37.7817557255921, -122.491851328976],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_3dbd6e1737fe8c04263afaa3162174ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_098dfa1a2dce810acf10138c33bdabe7 = $(`&lt;div id=&quot;html_098dfa1a2dce810acf10138c33bdabe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_3dbd6e1737fe8c04263afaa3162174ab.setContent(html_098dfa1a2dce810acf10138c33bdabe7);
#
#
#
#         marker_693e6deb8601b5b691efadbd746893ae.bindPopup(popup_3dbd6e1737fe8c04263afaa3162174ab)
#         ;
#
#
#
#
#             var marker_fdc821783233c4f706eaf9f53738b604 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_ff3aec79ab5f58b129db32735d4da825 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b48ba07cd4c53827e13b6f4ca64d3be3 = $(`&lt;div id=&quot;html_b48ba07cd4c53827e13b6f4ca64d3be3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_ff3aec79ab5f58b129db32735d4da825.setContent(html_b48ba07cd4c53827e13b6f4ca64d3be3);
#
#
#
#         marker_fdc821783233c4f706eaf9f53738b604.bindPopup(popup_ff3aec79ab5f58b129db32735d4da825)
#         ;
#
#
#
#
#             var marker_7da0371c79fec3f29e1057420e269e66 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_34e849948ab99fe68b2fc2bb849a2c97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f70f8c13699a10ad9387f47e91b8fd4 = $(`&lt;div id=&quot;html_6f70f8c13699a10ad9387f47e91b8fd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_34e849948ab99fe68b2fc2bb849a2c97.setContent(html_6f70f8c13699a10ad9387f47e91b8fd4);
#
#
#
#         marker_7da0371c79fec3f29e1057420e269e66.bindPopup(popup_34e849948ab99fe68b2fc2bb849a2c97)
#         ;
#
#
#
#
#             var marker_382975532cabb5fd58b2201173740b33 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_f62954999fceec049dcf9663dc00a626 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f4bfb35f5e5d5a23d92771b1625fd78 = $(`&lt;div id=&quot;html_6f4bfb35f5e5d5a23d92771b1625fd78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_f62954999fceec049dcf9663dc00a626.setContent(html_6f4bfb35f5e5d5a23d92771b1625fd78);
#
#
#
#         marker_382975532cabb5fd58b2201173740b33.bindPopup(popup_f62954999fceec049dcf9663dc00a626)
#         ;
#
#
#
#
#             var marker_6f3c2b55cccb22744cfc1c4bb55a0a0f = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_6fe721f3311151cdb3eb3c2f020cb32c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9392ce2e001da09813a35874cbd44efe = $(`&lt;div id=&quot;html_9392ce2e001da09813a35874cbd44efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_6fe721f3311151cdb3eb3c2f020cb32c.setContent(html_9392ce2e001da09813a35874cbd44efe);
#
#
#
#         marker_6f3c2b55cccb22744cfc1c4bb55a0a0

# %% [markdown]
# Add a circle in the map using `Folium Circle` for first 100 rows of the dataset.

# %%
for index, row in crime_csv.head(100).iterrows():
    folium.Circle(
        location=[row['Y'], row['X']],
        popup=f"Index: {index}").add_to(base_map)
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4f2024acb55de24c852f058e176e306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4f2024acb55de24c852f058e176e306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4f2024acb55de24c852f058e176e306 = L.map(
#                 &quot;map_b4f2024acb55de24c852f058e176e306&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#
#
#
#             var tile_layer_9cfc6c90b60ab1386086c845225d1d45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9cfc6c90b60ab1386086c845225d1d45.addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#             tile_layer_9cfc6c90b60ab1386086c845225d1d45.addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#             var marker_693e6deb8601b5b691efadbd746893ae = L.marker(
#                 [37.7817557255921, -122.491851328976],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_3dbd6e1737fe8c04263afaa3162174ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_098dfa1a2dce810acf10138c33bdabe7 = $(`&lt;div id=&quot;html_098dfa1a2dce810acf10138c33bdabe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_3dbd6e1737fe8c04263afaa3162174ab.setContent(html_098dfa1a2dce810acf10138c33bdabe7);
#
#
#
#         marker_693e6deb8601b5b691efadbd746893ae.bindPopup(popup_3dbd6e1737fe8c04263afaa3162174ab)
#         ;
#
#
#
#
#             var marker_fdc821783233c4f706eaf9f53738b604 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_ff3aec79ab5f58b129db32735d4da825 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b48ba07cd4c53827e13b6f4ca64d3be3 = $(`&lt;div id=&quot;html_b48ba07cd4c53827e13b6f4ca64d3be3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_ff3aec79ab5f58b129db32735d4da825.setContent(html_b48ba07cd4c53827e13b6f4ca64d3be3);
#
#
#
#         marker_fdc821783233c4f706eaf9f53738b604.bindPopup(popup_ff3aec79ab5f58b129db32735d4da825)
#         ;
#
#
#
#
#             var marker_7da0371c79fec3f29e1057420e269e66 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_34e849948ab99fe68b2fc2bb849a2c97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f70f8c13699a10ad9387f47e91b8fd4 = $(`&lt;div id=&quot;html_6f70f8c13699a10ad9387f47e91b8fd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_34e849948ab99fe68b2fc2bb849a2c97.setContent(html_6f70f8c13699a10ad9387f47e91b8fd4);
#
#
#
#         marker_7da0371c79fec3f29e1057420e269e66.bindPopup(popup_34e849948ab99fe68b2fc2bb849a2c97)
#         ;
#
#
#
#
#             var marker_382975532cabb5fd58b2201173740b33 = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_f62954999fceec049dcf9663dc00a626 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f4bfb35f5e5d5a23d92771b1625fd78 = $(`&lt;div id=&quot;html_6f4bfb35f5e5d5a23d92771b1625fd78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_f62954999fceec049dcf9663dc00a626.setContent(html_6f4bfb35f5e5d5a23d92771b1625fd78);
#
#
#
#         marker_382975532cabb5fd58b2201173740b33.bindPopup(popup_f62954999fceec049dcf9663dc00a626)
#         ;
#
#
#
#
#             var marker_6f3c2b55cccb22744cfc1c4bb55a0a0f = L.marker(
#                 [37.7126165766239, -122.413676487435],
#                 {}
#             ).addTo(map_b4f2024acb55de24c852f058e176e306);
#
#
#         var popup_6fe721f3311151cdb3eb3c2f020cb32c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9392ce2e001da09813a35874cbd44efe = $(`&lt;div id=&quot;html_9392ce2e001da09813a35874cbd44efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Date: 09/20/2015&lt;/div&gt;`)[0];
#                 popup_6fe721f3311151cdb3eb3c2f020cb32c.setContent(html_9392ce2e001da09813a35874cbd44efe);
#
#
#
#         marker_6f3c2b55cccb22744cfc1c4bb55a0a0

# %% [markdown]
# [BONUS] Create a heatmap of the incident happened in SF.

# %% [markdown]
# **HOMEWORK** Explore Folium as much as you can.
#
# **HOMEWORK** Explore GeoPandas

# %% [markdown]
# ## More Resources
#
# <a name="histfootnote">1</a>: [Histogram](https://en.wikipedia.org/wiki/Histogram)
#
# The matplotlib users' guide is at http://pageperso.lif.univ-mrs.fr/~francois.denis/IAAM1/Matplotlib.pdf.

# %% [markdown]
# For visualisation ideas and code see https://python-graph-gallery.com/:

# %% [markdown]
# 2: GeoPandas
#
# > The goal of GeoPandas is to make working with geospatial data in python easier. It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface to multiple geometries to shapely. GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.
#
# [GeoPandas 0.13.2](http://geopandas.org/index.html#)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
